# %% [markdown]
# ![WeChat4b7910d515eb06f07cca5baebedd340c.png](attachment:WeChat4b7910d515eb06f07cca5baebedd340c.png)
# ![WeChat23d361f5d99f608d919759223d723c32.png](attachment:WeChat23d361f5d99f608d919759223d723c32.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((100, 2))
X[:, 0] = np.random.uniform(0., 100., size = 100)
X[:, 1] = 0.75 * X[:,0] + 3. + np.random.normal(0., 10., size = 100)

# %%
from playML.PCA import PCA

pca = PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(n_components = 2)

# %%
pca.components_
# Out:
# array([[ 0.80194949,  0.59739184],
#        [ 0.59739804, -0.80194487]])

# %%
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(n_components = 1)

# %%
X_reduction = pca.transform(X)

# %%
X_reduction.shape
# Out:
# (100, 1)

# %%
X_restore = pca.inverse_transform(X_reduction)

# %%
plt.scatter(X[:, 0], X[:,1], color = 'b', alpha = 0.5)
plt.scatter(X_restore[:,0], X_restore[:,1], color = 'r', alpha=0.5)
plt.show()

# %% [markdown]
# 降维之后再还原，还原的结果是原来维度下的，主成分的方向上的点。在高维的空间表达这些低维的点

# %%
plt.scatter(X_reduction,np.ones(len(X_reduction)), color = 'b', alpha = 0.5)

# %% [markdown]
# ### sklearn中的pca

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=1, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[0.80194958, 0.59739172]])

# %%
X_reduction = pca.transform(X)

# %%
X_reduction.shape
# Out:
# (100, 1)

# %%
X_restore = pca.inverse_transform(X_reduction)

# %%
X_restore.shape
# Out:
# (100, 2)
