# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_lfw_people

# %%
faces = fetch_lfw_people()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0a8df4ec139d> in <module>
# ----> 1 faces = fetch_lfw_people()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/lfw.py in fetch_lfw_people(data_home, funneled, resize, min_faces_per_person, color, slice_, download_if_missing, return_X_y)
#     323     lfw_home, data_folder_path = _check_fetch_lfw(
#     324         data_home=data_home, funneled=funneled,
# --> 325         download_if_missing=download_if_missing)
#     326     logger.debug('Loading LFW people faces from %s', lfw_home)
#     327
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/lfw.py in _check_fetch_lfw(data_home, funneled, download_if_missing)
#     109             if download_if_missing:
#     110                 logger.info("Downloading LFW metadata: %s", target.url)
# ...

# %%
faces = fetch_lfw_people(data_home="/Users/apple/scikit_learn_data/")

# %% [markdown]
# 加载不出来数据集，放弃了
